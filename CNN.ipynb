# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

# %%
df = pd.read_csv('Unified-1.csv', low_memory = False)

# %%
df.isna()
# Out:
#          DATE   TIME  STATION  LATITUDE  LONGITUDE  ELEVATION  TEMPERATURE  \
# 0       False  False    False     False      False      False        False
# 1       False  False    False     False      False      False        False
# 2       False  False    False     False      False      False        False
# 3       False  False    False     False      False      False        False
# 4       False  False    False     False      False      False        False
# ...       ...    ...      ...       ...        ...        ...          ...
# 131208  False  False    False     False      False      False        False
# 131209  False  False    False     False      False      False        False
# 131210  False  False    False     False      False      False        False
# 131211  False  False    False     False      False      False        False
# 131212  False  False    False     False      False      False        False
#
#         RELATIVE HUMIDITY  ACTUAL VAPOR PRESSURE  DEWPOINT TEMPERATURE  \
# 0                   False                  False                 False
# 1                   False                  False                 False
# 2                   False                  False                 False
# 3                   False                  False                 False
# 4                   False                  False                 False
# ...                   ...                    ...                   ...
# 131208              False                  False                 False
# 131209              False                  False                 False
# 131210              False                  False                 False
# 131211              False                  False                 False
# 131212              False                  False                 False
#
#         WIND DIRECTION  WIND GUST  WIND SPEED  GLOBAL SOLAR RADIATION  \
# 0                False      False       False                   False
# 1                False      False       False                   False
# 2                False      False       False                   False
# 3                False      False       False                   False
# 4                False      False       False                   False
# ...                ...        ...         ...                     ...
# 131208           False      False       False                   False
# 131209           False      False       False                   False
# 131210           False      False       False                   False
# 131211           False      False       False                   False
# 131212           False      False       False                   False
#
#         SOLAR RADIATION/MIN  PRECIPITATION  BAROMETRIC PRESSURE
# 0                     False          False                False
# 1                     False          False                False
# 2                     False          False                False
# 3                     False          False                False
# 4                     False          False                False
# ...                     ...            ...                  ...
# 131208                False          False                 True
# 131209                False          False                 True
# 131210                False          False                 True
# 131211                False          False                 True
# 131212                False          False                 True
#
# [131213 rows x 17 columns]

# %%
date_obj = pd.to_datetime(df['DATE'], format ='%m/%d/%Y')
df['date']= date_obj

df['hour'] = df['TIME'].str.split(':').apply(lambda x: int(x[0]) + int(x[1]) / 60)
df.dtypes
# Out:
# DATE                              object
# TIME                              object
# STATION                           object
# LATITUDE                          object
# LONGITUDE                         object
# ELEVATION                         object
# TEMPERATURE                       object
# RELATIVE HUMIDITY                 object
# ACTUAL VAPOR PRESSURE            float64
# DEWPOINT TEMPERATURE              object
# WIND DIRECTION                   float64
# WIND GUST                        float64
# WIND SPEED                       float64
# GLOBAL SOLAR RADIATION           float64
# SOLAR RADIATION/MIN              float64
# PRECIPITATION                    float64
# BAROMETRIC PRESSURE              float64
# date                      datetime64[ns]
# hour                             float64
# dtype: object

# %%
df['TEMPERATURE'] = df['TEMPERATURE'].str.replace('-', ' ').str.replace('+', ' ')
df['RELATIVE HUMIDITY'] = df['RELATIVE HUMIDITY'].str.replace('-', ' ').str.replace('+', ' ')
df['DEWPOINT TEMPERATURE'] = df['DEWPOINT TEMPERATURE'].str.replace('-', ' ').str.replace('+', ' ')

df[['TEMPERATURE', 'RELATIVE HUMIDITY', 'DEWPOINT TEMPERATURE']] = df[['TEMPERATURE', 'RELATIVE HUMIDITY', 'DEWPOINT TEMPERATURE']].astype(float)

# %%
df.fillna(value = 0, inplace = True)
df
# Out:
#               DATE   TIME               STATION    LATITUDE     LONGITUDE  \
# 0       01/01/2019   0:00      Grand Coulee Dam  47.94527 N  -118.95361 W
# 1       01/01/2019   1:00      Grand Coulee Dam  47.94527 N  -118.95361 W
# 2       01/01/2019   2:00      Grand Coulee Dam  47.94527 N  -118.95361 W
# 3       01/01/2019   3:00      Grand Coulee Dam  47.94527 N  -118.95361 W
# 4       01/01/2019   4:00      Grand Coulee Dam  47.94527 N  -118.95361 W
# ...            ...    ...                   ...         ...           ...
# 131208  01/01/2022  19:00  Entiat Fish Hatchery  47.69796 N  -120.32373 W
# 131209  01/01/2022  20:00  Entiat Fish Hatchery  47.69796 N  -120.32373 W
# 131210  01/01/2022  21:00  Entiat Fish Hatchery  47.69796 N  -120.32373 W
# 131211  01/01/2022  22:00  Entiat Fish Hatchery  47.69796 N  -120.32373 W
# 131212  01/01/2022  23:00  Entiat Fish Hatchery  47.69796 N  -120.32373 W
#
#        ELEVATION  TEMPERATURE  RELATIVE HUMIDITY  ACTUAL VAPOR PRESSURE  \
# 0          1320'        27.13              78.57                   0.39
# 1          1320'        27.55              76.13                   0.39
# 2          1320'        27.20              74.20                   0.37
# 3          1320'        27.41              77.32                   0.39
# 4          1320'        28.04              79.24                   0.41
# ...          ...          ...                ...                    ...
# 131208     1033'        12.60              82.60                   0.22
# 131209     1033'        12.83              78.70                   0.21
# 131210     1033'        12.73              76.28                   0.21
# 131211     1033'        11.19              78.99                   0.20
# 131212     1033'         9.48              82.00                   0.19
#
#         DEWPOINT TEMPERATURE  WIND DIRECTION  WIND GUST  WIND SPEED  \
# 0                      21.35           200.1       5.92        2.00
# 1                      21.03           253.4       5.48        2.54
# 2                      20.08           295.2       3.51        1.87
# 3                      21.25           260.2       4.16        2.10
# 4                      22.44           166.1       3.95        1.22
# ...                      ...             ...        ...         ...
# 131208                  8.31           197.7       0.88        0.10
# 131209                  7.45           337.1       3.95        1.50
# 131210                  6.68           320.5       4.16        1.91
# 131211                  5.94           336.2       4.38        1.65
# 131212                  5.10           345.3       5.48        2.08
#
#         GLOBAL SOLAR RADIATION  SOLAR RADIATION/MIN  PRECIPITATION  \
# 0                       2343.0                  0.0          12.98
# 1                       2343.0                  0.0          12.98
# 2                       2343.0                  0.0          12.98
# 3                       2343.0                  0.0          12.98
# 4                       2343.0                  0.0          12.98
# ...                        ...                  ...            ...
# 131208                  5763.0                  0.0           9.28
# 131209                  5763.0                  0.0           9.29
# 131210                  5763.0                  0.0           9.29
# 131211                  5763.0                  0.0           9.28
# 131212                  5763.0                  0.0           9.28
#
#         BAROMETRIC PRESSURE       date  hour
# 0                     30.41 2019-01-01   0.0
# 1                     30.40 2019-01-01   1.0
# 2                     30.40 2019-01-01   2.0
# 3                     30.39 2019-01-01   3.0
# 4                     30.37 2019-01-01   4.0
# ...                     ...        ...   ...
# 131208                 0.00 2022-01-01  19.0
# 131209                 0.00 2022-01-01  20.0
# 131210                 0.00 2022-01-01  21.0
# 131211                 0.00 2022-01-01  22.0
# 131212                 0.00 2022-01-01  23.0
#
# [131213 rows x 19 columns]

# %%
df['date_float']= df['date'].astype('int64')/10**9

# %%
X = df[['date_float','hour','TEMPERATURE', 'RELATIVE HUMIDITY', 'ACTUAL VAPOR PRESSURE', 'DEWPOINT TEMPERATURE', 'WIND DIRECTION', 'WIND GUST', 'WIND SPEED','SOLAR RADIATION/MIN','PRECIPITATION', 'BAROMETRIC PRESSURE']].values
y = df['GLOBAL SOLAR RADIATION'].values.reshape(-1, 1)  
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=70)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=70)


# Standardize features
scaler1 = StandardScaler()
scaler2 = StandardScaler()
X_train_scaled = scaler1.fit_transform(X_train)
X_val_scaled = scaler1.transform(X_val)
X_test_scaled = scaler1.transform(X_test)
y_train_scaled = scaler2.fit_transform(y_train)
y_val_scaled = scaler2.transform(y_val)
y_test_scaled = scaler2.transform(y_test)

#print(f"{X_train.shape} {X_val.shape} :: {X_test.shape}" )

# %%
# Convert numpy arrays to PyTorch tensors
X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train_scaled, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val_scaled, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val_scaled, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test_scaled, dtype=torch.float32)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ComplexCNNModel(nn.Module):
    def __init__(self):
        super(ComplexCNNModel, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=5, stride=1, padding=2)
        self.bn1 = nn.BatchNorm1d(64)  
        self.conv2 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=2)
        self.bn2 = nn.BatchNorm1d(128)  
        self.conv3 = nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm1d(256)  
        
        # Define fully connected layers with increased depth
        self.fc1 = nn.Linear(256 * 1, 512)  # Adjusted input size
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 1)  # Output layer
        self.dropout = nn.Dropout(p=0.85)

    def forward(self, x):
        x = x.unsqueeze(1)  # Add a channel dimension
        
        # Apply convolutional layers with increased complexity
        x = self.bn1(F.relu(self.conv1(x)))
        x = F.max_pool1d(x, kernel_size=2, stride=2)
        x = self.bn2(F.relu(self.conv2(x)))
        x = F.max_pool1d(x, kernel_size=2, stride=2)
        x = self.bn3(F.leaky_relu(self.conv3(x)))
        x = F.max_pool1d(x, kernel_size=2, stride=2)
        
        # Flatten the output for fully connected layers
        x = x.view(-1, 256 * 1)  # Adjusted input size
        
        # Apply fully connected layers with increased depth
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.leaky_relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return x

# Instantiate the complex model
model = ComplexCNNModel()
print(model)
# Out:
# ComplexCNNModel(
#   (conv1): Conv1d(1, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(64, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(128, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#   (bn3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=256, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.85, inplace=False)
# )

# %%
batch_size = 72
learning_rate = 0.0001

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Xavier initialization
for layer in [model.fc1, model.fc2, model.fc3]:
    nn.init.xavier_uniform_(layer.weight)

# Define loss function and optimizer
criterion = nn.MSELoss()  # Using Mean Squared Error loss for regression
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=0.01)

train_losses = []
valid_losses = []
test_losses = []

num_epochs = 100  # Set a meaningful number of epochs
for epoch in range(num_epochs):
    train_loss = 0
    valid_loss = 0
    test_loss = 0
    
    model.train()  
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)
    
    model.eval()
    with torch.no_grad():
        for inputs, labels in val_loader:
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            valid_loss += loss.item() * inputs.size(0)
            
            
    model.eval()
    with torch.no_grad():
        for inputs, labels in test_loader:
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item() * inputs.size(0)
    
    # Calculate average loss per sample for the epoch
    train_loss /= len(train_loader.dataset)
    valid_loss /= len(val_loader.dataset)
    test_loss /= len(test_loader.dataset)
    if (epoch+1) % 1 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Valid Loss: {valid_loss:.4f}, Test Loss: {test_loss: .4f}')
    
    # Append losses to the lists
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    test_losses.append(test_loss)

# Evaluation 
model.eval()  
with torch.no_grad():
    train_loss = 0
    for inputs, labels in train_loader:
        outputs = model(inputs)
        train_loss += criterion(outputs, labels).item() * inputs.size(0)
    train_loss /= len(train_loader.dataset)
    print(f'Train Loss: {train_loss:.4f}')

model.eval()  
with torch.no_grad():
    valid_loss = 0
    for inputs, labels in val_loader:
        outputs = model(inputs)
        valid_loss += criterion(outputs, labels).item() * inputs.size(0)
    valid_loss /= len(val_loader.dataset)
    print(f'Validation Loss: {valid_loss:.4f}')
    
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        test_loss += loss.item() * inputs.size(0)
    test_loss /= len(test_loader.dataset)
    print(f'Test Loss: {test_loss:.4f}')
    
        
 
# Plotting the training and validation losses

plt.plot(range(num_epochs), train_losses, label='Training Loss')
plt.plot(range(num_epochs), valid_losses, label='Validation Loss')
plt.plot(range(num_epochs), test_losses, label='Test Loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training, Validation and Test Losses')
plt.legend()
plt.show()
# Out:
# Epoch [1/100], Train Loss: 4.5095, Valid Loss: 1.0045, Test Loss:  1.0065
# Epoch [2/100], Train Loss: 1.1293, Valid Loss: 0.9999, Test Loss:  1.0018
# Epoch [3/100], Train Loss: 1.0205, Valid Loss: 0.9985, Test Loss:  1.0002
# Epoch [4/100], Train Loss: 1.0046, Valid Loss: 0.9971, Test Loss:  0.9987
# Epoch [5/100], Train Loss: 1.0015, Valid Loss: 0.9976, Test Loss:  0.9992
# Epoch [6/100], Train Loss: 0.9993, Valid Loss: 0.9970, Test Loss:  0.9986
# Epoch [7/100], Train Loss: 0.9982, Valid Loss: 0.9964, Test Loss:  0.9980
# Epoch [8/100], Train Loss: 0.9975, Valid Loss: 0.9953, Test Loss:  0.9970
# Epoch [9/100], Train Loss: 0.9949, Valid Loss: 0.9912, Test Loss:  0.9928
# Epoch [10/100], Train Loss: 0.9911, Valid Loss: 0.9881, Test Loss:  0.9891
# Epoch [11/100], Train Loss: 0.9835, Valid Loss: 0.9766, Test Loss:  0.9778
# Epoch [12/100], Train Loss: 0.9735, Valid Loss: 0.9634, Test Loss:  0.9639
# Epoch [13/100], Train Loss: 0.9644, Valid Loss: 0.9565, Test Loss:  0.9563
# Epoch [14/100], Train Loss: 0.9555, Valid Loss: 0.9495, Test Loss:  0.9491
# Epoch [15/100], Train Loss: 0.9479, Valid Loss: 0.9479, Test Loss:  0.9468
# Epoch [16/100], Train Loss: 0.9389, Valid Loss: 0.9384, Test Loss:  0.9374
# Epoch [17/100], Train Loss: 0.9345, Valid Loss: 0.9312, Test Loss:  0.9299
# Epoch [18/100], Train Loss: 0.9271, Valid Loss: 0.9291, Test Loss:  0.9268
# Epoch [19/100], Train Loss: 0.9198, Valid Loss: 0.9250, Test Loss:  0.9219
# Epoch [20/100], Train Loss: 0.9158, Valid Loss: 0.9193, Test Loss:  0.9163
# Epoch [21/100], Train Loss: 0.9092, Valid Loss: 0.9135, Test Loss:  0.9103
# Epoch [22/100], Train Loss: 0.9036, Valid Loss: 0.9097, Test Loss:  0.9055
# Epoch [23/100], Train Loss: 0.8972, Valid Loss: 0.9073, Test Loss:  0.9027
# Epoch [24/100], Train Loss: 0.8942, Valid Loss: 0.9071, Test Loss:  0.9023
# Epoch [25/100], Train Loss: 0.8885, Valid Loss: 0.8994, Test Loss:  0.8935
# Epoch [26/100], Train Loss: 0.8845, Valid Loss: 0.8978, Test Loss:  0.8917
# Epoch [27/100], Train Loss: 0.8786, Valid Loss: 0.8971, Test Loss:  0.8898
# Epoch [28/100], Train Loss: 0.8766, Valid Loss: 0.9019, Test Loss:  0.8944
# Epoch [29/100], Train Loss: 0.8724, Valid Loss: 0.8887, Test Loss:  0.8803
# Epoch [30/100], Train Loss: 0.8686, Valid Loss: 0.8861, Test Loss:  0.8770
# Epoch [31/100], Train Loss: 0.8661, Valid Loss: 0.8878, Test Loss:  0.8777
# Epoch [32/100], Train Loss: 0.8613, Valid Loss: 0.8867, Test Loss:  0.8756
# Epoch [33/100], Train Loss: 0.8578, Valid Loss: 0.8882, Test Loss:  0.8783
# Epoch [34/100], Train Loss: 0.8549, Valid Loss: 0.8826, Test Loss:  0.8721
# Epoch [35/100], Train Loss: 0.8508, Valid Loss: 0.8876, Test Loss:  0.8780
# Epoch [36/100], Train Loss: 0.8468, Valid Loss: 0.8788, Test Loss:  0.8673
# Epoch [37/100], Train Loss: 0.8452, Valid Loss: 0.8800, Test Loss:  0.8678
# Epoch [38/100], Train Loss: 0.8424, Valid Loss: 0.8806, Test Loss:  0.8660
# Epoch [39/100], Train Loss: 0.8386, Valid Loss: 0.8751, Test Loss:  0.8601
# Epoch [40/100], Train Loss: 0.8369, Valid Loss: 0.8763, Test Loss:  0.8624
# Epoch [41/100], Train Loss: 0.8331, Valid Loss: 0.8804, Test Loss:  0.8655
# Epoch [42/100], Train Loss: 0.8300, Valid Loss: 0.8730, Test Loss:  0.8587
# Epoch [43/100], Train Loss: 0.8280, Valid Loss: 0.8741, Test Loss:  0.8586
# Epoch [44/100], Train Loss: 0.8272, Valid Loss: 0.8794, Test Loss:  0.8624
# Epoch [45/100], Train Loss: 0.8238, Valid Loss: 0.8736, Test Loss:  0.8560
# Epoch [46/100], Train Loss: 0.8234, Valid Loss: 0.8822, Test Loss:  0.8628
# Epoch [47/100], Train Loss: 0.8181, Valid Loss: 0.8765, Test Loss:  0.8579
# Epoch [48/100], Train Loss: 0.8146, Valid Loss: 0.8646, Test Loss:  0.8469
# Epoch [49/100], Train Loss: 0.8145, Valid Loss: 0.8687, Test Loss:  0.8487
# Epoch [50/100], Train Loss: 0.8113, Valid Loss: 0.8680, Test Loss:  0.8491
# Epoch [51/100], Train Loss: 0.8089, Valid Loss: 0.8658, Test Loss:  0.8456
# Epoch [52/100], Train Loss: 0.8082, Valid Loss: 0.8682, Test Loss:  0.8488
# Epoch [53/100], Train Loss: 0.8073, Valid Loss: 0.8669, Test Loss:  0.8476
# Epoch [54/100], Train Loss: 0.8047, Valid Loss: 0.8641, Test Loss:  0.8450
# Epoch [55/100], Train Loss: 0.8024, Valid Loss: 0.8708, Test Loss:  0.8497
# Epoch [56/100], Train Loss: 0.8035, Valid Loss: 0.8694, Test Loss:  0.8490
# Epoch [57/100], Train Loss: 0.7998, Valid Loss: 0.8623, Test Loss:  0.8414
# Epoch [58/100], Train Loss: 0.7992, Valid Loss: 0.8710, Test Loss:  0.8503
# Epoch [59/100], Train Loss: 0.7952, Valid Loss: 0.8682, Test Loss:  0.8459
# Epoch [60/100], Train Loss: 0.7954, Valid Loss: 0.8678, Test Loss:  0.8429
# Epoch [61/100], Train Loss: 0.7918, Valid Loss: 0.8610, Test Loss:  0.8393
# Epoch [62/100], Train Loss: 0.7913, Valid Loss: 0.8614, Test Loss:  0.8406
# Epoch [63/100], Train Loss: 0.7927, Valid Loss: 0.8617, Test Loss:  0.8383
# Epoch [64/100], Train Loss: 0.7881, Valid Loss: 0.8704, Test Loss:  0.8477
# Epoch [65/100], Train Loss: 0.7885, Valid Loss: 0.8596, Test Loss:  0.8362
# Epoch [66/100], Train Loss: 0.7869, Valid Loss: 0.8633, Test Loss:  0.8407
# Epoch [67/100], Train Loss: 0.7835, Valid Loss: 0.8715, Test Loss:  0.8465
# Epoch [68/100], Train Loss: 0.7839, Valid Loss: 0.8605, Test Loss:  0.8371
# Epoch [69/100], Train Loss: 0.7806, Valid Loss: 0.8743, Test Loss:  0.8492
# Epoch [70/100], Train Loss: 0.7825, Valid Loss: 0.8608, Test Loss:  0.8356
# Epoch [71/100], Train Loss: 0.7799, Valid Loss: 0.8641, Test Loss:  0.8380
# Epoch [72/100], Train Loss: 0.7781, Valid Loss: 0.8605, Test Loss:  0.8360
# Epoch [73/100], Train Loss: 0.7765, Valid Loss: 0.8617, Test Loss:  0.8346
# Epoch [74/100], Train Loss: 0.7751, Valid Loss: 0.8670, Test Loss:  0.8400
# Epoch [75/100], Train Loss: 0.7773, Valid Loss: 0.8735, Test Loss:  0.8473
# Epoch [76/100], Train Loss: 0.7735, Valid Loss: 0.8645, Test Loss:  0.8381
# Epoch [77/100], Train Loss: 0.7729, Valid Loss: 0.8614, Test Loss:  0.8341
# Epoch [78/100], Train Loss: 0.7739, Valid Loss: 0.8664, Test Loss:  0.8394
# Epoch [79/100], Train Loss: 0.7716, Valid Loss: 0.8643, Test Loss:  0.8381
# Epoch [80/100], Train Loss: 0.7709, Valid Loss: 0.8666, Test Loss:  0.8416
# Epoch [81/100], Train Loss: 0.7703, Valid Loss: 0.8614, Test Loss:  0.8342
# Epoch [82/100], Train Loss: 0.7675, Valid Loss: 0.8654, Test Loss:  0.8371
# Epoch [83/100], Train Loss: 0.7673, Valid Loss: 0.8594, Test Loss:  0.8325
# Epoch [84/100], Train Loss: 0.7649, Valid Loss: 0.8563, Test Loss:  0.8293
# Epoch [85/100], Train Loss: 0.7653, Valid Loss: 0.8584, Test Loss:  0.8301
# Epoch [86/100], Train Loss: 0.7643, Valid Loss: 0.8645, Test Loss:  0.8364
# Epoch [87/100], Train Loss: 0.7642, Valid Loss: 0.8606, Test Loss:  0.8336
# Epoch [88/100], Train Loss: 0.7636, Valid Loss: 0.8645, Test Loss:  0.8354
# Epoch [89/100], Train Loss: 0.7617, Valid Loss: 0.8601, Test Loss:  0.8334
# Epoch [90/100], Train Loss: 0.7630, Valid Loss: 0.8554, Test Loss:  0.8275
# Epoch [91/100], Train Loss: 0.7597, Valid Loss: 0.8616, Test Loss:  0.8315
# Epoch [92/100], Train Loss: 0.7596, Valid Loss: 0.8653, Test Loss:  0.8376
# Epoch [93/100], Train Loss: 0.7608, Valid Loss: 0.8708, Test Loss:  0.8410
# Epoch [94/100], Train Loss: 0.7602, Valid Loss: 0.8617, Test Loss:  0.8314
# Epoch [95/100], Train Loss: 0.7582, Valid Loss: 0.8611, Test Loss:  0.8309
# Epoch [96/100], Train Loss: 0.7553, Valid Loss: 0.8667, Test Loss:  0.8360
# Epoch [97/100], Train Loss: 0.7562, Valid Loss: 0.8582, Test Loss:  0.8278
# Epoch [98/100], Train Loss: 0.7566, Valid Loss: 0.8574, Test Loss:  0.8267
# Epoch [99/100], Train Loss: 0.7548, Valid Loss: 0.8625, Test Loss:  0.8317
# Epoch [100/100], Train Loss: 0.7536, Valid Loss: 0.8598, Test Loss:  0.8303
# Train Loss: 0.7030
# Validation Loss: 0.8598
# Test Loss: 0.8303

# %%
actual_values = []  
predicted_values = []  

Time = df['hour'][:24]
Time_str = [str(hour) for hour in Time]

for inputs, labels in test_loader:
    outputs = model(inputs)
    actual_values.extend(labels.detach().numpy())
    predicted_values.extend(outputs.detach().numpy())


fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(Time_str, actual_values[:24], color='blue',marker='x', label='Actual')
ax.plot(Time_str, predicted_values[:24], color='orange', marker='o', label='Predicted')

ax.set_xlabel('Time')
ax.set_ylabel('Value')

ax.legend(loc='upper center')

ax.set_xticklabels(Time_str, rotation=90)

ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/x7/_r8bw_1n571f46bh_8p4kw3m0000gp/T/ipykernel_89132/1998358245.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(Time_str, rotation=90)

# %%
actual_values = []  
predicted_values = []  

Time = df['hour'][:24]
Time_str = [str(hour) for hour in Time]

for inputs, labels in test_loader:
    outputs = model(inputs)
    actual_values.extend(labels.detach().numpy())
    predicted_values.extend(outputs.detach().numpy())


fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(Time_str, actual_values[:24], color='blue',marker='x', label='Actual')
ax.plot(Time_str, predicted_values[:24], color='orange', marker='o', label='Predicted')

ax.set_xlabel('Time')
ax.set_ylabel('Value')

ax.legend(loc='upper center')

ax.set_xticklabels(Time_str, rotation=90)

ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/x7/_r8bw_1n571f46bh_8p4kw3m0000gp/T/ipykernel_89132/1998358245.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(Time_str, rotation=90)

# %%
actual_values = []  
predicted_values = []  

Time = df['hour'][:24]
Time_str = [str(hour) for hour in Time]

for inputs, labels in test_loader:
    outputs = model(inputs)
    actual_values.extend(labels.detach().numpy())
    predicted_values.extend(outputs.detach().numpy())


fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(Time_str, actual_values[:24], color='blue',marker='x', label='Actual')
ax.plot(Time_str, predicted_values[:24], color='orange', marker='o', label='Predicted')

ax.set_xlabel('Time')
ax.set_ylabel('Value')

ax.legend(loc='upper center')

ax.set_xticklabels(Time_str, rotation=90)

ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/x7/_r8bw_1n571f46bh_8p4kw3m0000gp/T/ipykernel_89132/1998358245.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(Time_str, rotation=90)

# %%
from sklearn.metrics import r2_score

# Switch model to evaluation mode
model.eval()

# Lists to store actual and predicted values
actual_values = []
predicted_values = []

# Iterate over the validation or test loader
with torch.no_grad():
    for inputs, labels in val_loader:  # Use val_loader or test_loader
        outputs = model(inputs)
        actual_values.extend(labels.tolist())
        predicted_values.extend(outputs.tolist())

# Calculate R^2 score
r2 = r2_score(actual_values, predicted_values)
print("Val R^2 score:", r2)


from sklearn.metrics import r2_score

# Switch model to evaluation mode
model.eval()

# Lists to store actual and predicted values
actual_values = []
predicted_values = []

# Iterate over the validation or test loader
with torch.no_grad():
    for inputs, labels in test_loader:  # Use val_loader or test_loader
        outputs = model(inputs)
        actual_values.extend(labels.tolist())
        predicted_values.extend(outputs.tolist())

# Calculate R^2 score
r2 = r2_score(actual_values, predicted_values)
print("Test R^2 score:", r2)
# Out:
# Val R^2 score: 0.11931010721664581
# Test R^2 score: 0.15310364933525278
